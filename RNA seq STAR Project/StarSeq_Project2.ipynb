# %% [markdown]
# # PH 721: Intro. to Trans. Bioinformatics
# ## Project 2
#
# **Student: Justin Womack**

# %% [markdown]
# The aim of this project is to  perform alignment and quantification in STAR, and DE and GO/pathway anlaysis.
#
# Project name: **Identifying dormant cells in colorectal cancer spheroids (human)**
#
# The project can be found in: https://www.ncbi.nlm.nih.gov/Traces/study/?acc=PRJNA454881&go=go.

# %% [markdown]
# ### 1. Data download

# %% [markdown]
# The data was manually downloaded thru the SRA Run Selector in https://www.ncbi.nlm.nih.gov/Traces/study/, using the Project Accession: **PRJNA454881**. The downloaded file was renamed `all_samples.txt`, and then used thru the rest of the processing pipeline.
#
# In the line directly below, the header of `all_samples.txt` was removed, and stored in `samples.txt`.

# %%
sed '1d' all_samples.txt > samples.txt
# head -16 all_samples.txt2 > samples.txt
# rm all_samples.txt2

# %% [markdown]
# Below the `sra_files` folder is made, for which the SRA files listed in `all_samples.txt` will be downloaded to.

# %%
mkdir -p sra_files

# %% [markdown]
# Below is the code to perform the actual download of the data to the `sra_files` folder.

# %%
cut -f5 samples.txt | xargs -i sh -c \
'v={}; FTPROOT=ftp://ftp-trace.ncbi.nih.gov/;\
REM=sra/sra-instant/reads/ByRun/sra/;\
url=${FTPROOT}${REM}${v:0:3}/${v:0:6}/${v}/${v}.sra;\
wget $url -P sra_files'
# Out:
# --2019-05-03 12:23:52--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108388/SRR7108388.sra
#            => ‘sra_files/SRR7108388.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.7
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108388 ... done.
# ==> SIZE SRR7108388.sra ... 265858419
# ==> PASV ... done.    ==> RETR SRR7108388.sra ... done.
# Length: 265858419 (254M) (unauthoritative)
#
# 100%[======================================>] 265,858,419 45.8MB/s   in 5.9s
#
# 2019-05-03 12:23:59 (43.2 MB/s) - ‘sra_files/SRR7108388.sra’ saved [265858419]
#
# --2019-05-03 12:23:59--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108389/SRR7108389.sra
#            => ‘sra_files/SRR7108389.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.7
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108389 ... done.
# ==> SIZE SRR7108389.sra ... 274088773
# ==> PASV ... done.    ==> RETR SRR7108389.sra ... done.
# Length: 274088773 (261M) (unauthoritative)
#
# 100%[======================================>] 274,088,773 47.9MB/s   in 5.8s
#
# 2019-05-03 12:24:06 (45.0 MB/s) - ‘sra_files/SRR7108389.sra’ saved [274088773]
#
# --2019-05-03 12:24:06--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108390/SRR7108390.sra
#            => ‘sra_files/SRR7108390.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.13
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108390 ... done.
# ==> SIZE SRR7108390.sra ... 268167739
# ==> PASV ... done.    ==> RETR SRR7108390.sra ... done.
# Length: 268167739 (256M) (unauthoritative)
#
# 100%[======================================>] 268,167,739 51.3MB/s   in 5.5s
#
# 2019-05-03 12:24:12 (46.7 MB/s) - ‘sra_files/SRR7108390.sra’ saved [268167739]
#
# --2019-05-03 12:24:12--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108391/SRR7108391.sra
#            => ‘sra_files/SRR7108391.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.12
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108391 ... done.
# ==> SIZE SRR7108391.sra ... 248919079
# ==> PASV ... done.    ==> RETR SRR7108391.sra ... done.
# Length: 248919079 (237M) (unauthoritative)
#
# 100%[======================================>] 248,919,079 43.3MB/s   in 5.7s
#
# 2019-05-03 12:24:18 (41.3 MB/s) - ‘sra_files/SRR7108391.sra’ saved [248919079]
#
# --2019-05-03 12:24:18--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108392/SRR7108392.sra
#            => ‘sra_files/SRR7108392.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.7
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108392 ... done.
# ==> SIZE SRR7108392.sra ... 274671110
# ==> PASV ... done.    ==> RETR SRR7108392.sra ... done.
# Length: 274671110 (262M) (unauthoritative)
#
# 100%[======================================>] 274,671,110 47.4MB/s   in 5.8s
#
# 2019-05-03 12:24:25 (44.8 MB/s) - ‘sra_files/SRR7108392.sra’ saved [274671110]
#
# --2019-05-03 12:24:25--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108393/SRR7108393.sra
#            => ‘sra_files/SRR7108393.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.12
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108393 ... done.
# ==> SIZE SRR7108393.sra ... 289981778
# ==> PASV ... done.    ==> RETR SRR7108393.sra ... done.
# Length: 289981778 (277M) (unauthoritative)
#
# 100%[======================================>] 289,981,778 42.8MB/s   in 6.7s
#
# 2019-05-03 12:24:32 (41.6 MB/s) - ‘sra_files/SRR7108393.sra’ saved [289981778]
#
# --2019-05-03 12:24:32--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108394/SRR7108394.sra
#            => ‘sra_files/SRR7108394.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.7
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108394 ... done.
# ==> SIZE SRR7108394.sra ... 317647463
# ==> PASV ... done.    ==> RETR SRR7108394.sra ... done.
# Length: 317647463 (303M) (unauthoritative)
#
# 100%[======================================>] 317,647,463 48.8MB/s   in 6.9s
#
# 2019-05-03 12:24:40 (43.8 MB/s) - ‘sra_files/SRR7108394.sra’ saved [317647463]
#
# --2019-05-03 12:24:40--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108395/SRR7108395.sra
#            => ‘sra_files/SRR7108395.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.13
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108395 ... done.
# ==> SIZE SRR7108395.sra ... 261174734
# ==> PASV ... done.    ==> RETR SRR7108395.sra ... done.
# Length: 261174734 (249M) (unauthoritative)
#
# 100%[======================================>] 261,174,734 44.0MB/s   in 6.0s
#
# 2019-05-03 12:24:46 (41.6 MB/s) - ‘sra_files/SRR7108395.sra’ saved [261174734]
#
# --2019-05-03 12:24:46--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108396/SRR7108396.sra
#            => ‘sra_files/SRR7108396.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.12
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.12|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108396 ... done.
# ==> SIZE SRR7108396.sra ... 309905572
# ==> PASV ... done.    ==> RETR SRR7108396.sra ... done.
# Length: 309905572 (296M) (unauthoritative)
#
# 100%[======================================>] 309,905,572 48.6MB/s   in 6.8s
#
# 2019-05-03 12:24:54 (43.4 MB/s) - ‘sra_files/SRR7108396.sra’ saved [309905572]
#
# --2019-05-03 12:24:54--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108397/SRR7108397.sra
#            => ‘sra_files/SRR7108397.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.13
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108397 ... done.
# ==> SIZE SRR7108397.sra ... 262281864
# ==> PASV ... done.    ==> RETR SRR7108397.sra ... done.
# Length: 262281864 (250M) (unauthoritative)
#
# 100%[======================================>] 262,281,864 45.6MB/s   in 5.9s
#
# 2019-05-03 12:25:00 (42.4 MB/s) - ‘sra_files/SRR7108397.sra’ saved [262281864]
#
# --2019-05-03 12:25:00--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108398/SRR7108398.sra
#            => ‘sra_files/SRR7108398.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.13
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108398 ... done.
# ==> SIZE SRR7108398.sra ... 283823768
# ==> PASV ... done.    ==> RETR SRR7108398.sra ... done.
# Length: 283823768 (271M) (unauthoritative)
#
# 100%[======================================>] 283,823,768 42.7MB/s   in 6.4s
#
# 2019-05-03 12:25:07 (42.3 MB/s) - ‘sra_files/SRR7108398.sra’ saved [283823768]
#
# --2019-05-03 12:25:07--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108399/SRR7108399.sra
#            => ‘sra_files/SRR7108399.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.13
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108399 ... done.
# ==> SIZE SRR7108399.sra ... 322992465
# ==> PASV ... done.    ==> RETR SRR7108399.sra ... done.
# Length: 322992465 (308M) (unauthoritative)
#
# 100%[======================================>] 322,992,465 47.5MB/s   in 6.9s
#
# 2019-05-03 12:25:15 (44.9 MB/s) - ‘sra_files/SRR7108399.sra’ saved [322992465]
#
# --2019-05-03 12:25:15--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108400/SRR7108400.sra
#            => ‘sra_files/SRR7108400.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.11
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.11|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108400 ... done.
# ==> SIZE SRR7108400.sra ... 305583399
# ==> PASV ... done.    ==> RETR SRR7108400.sra ... done.
# Length: 305583399 (291M) (unauthoritative)
#
# 100%[======================================>] 305,583,399 44.2MB/s   in 6.9s
#
# 2019-05-03 12:25:22 (42.3 MB/s) - ‘sra_files/SRR7108400.sra’ saved [305583399]
#
# --2019-05-03 12:25:22--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108401/SRR7108401.sra
#            => ‘sra_files/SRR7108401.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.13
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.13|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108401 ... done.
# ==> SIZE SRR7108401.sra ... 258351580
# ==> PASV ... done.    ==> RETR SRR7108401.sra ... done.
# Length: 258351580 (246M) (unauthoritative)
#
# 100%[======================================>] 258,351,580 49.4MB/s   in 5.7s
#
# 2019-05-03 12:25:29 (43.6 MB/s) - ‘sra_files/SRR7108401.sra’ saved [258351580]
#
# --2019-05-03 12:25:29--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108402/SRR7108402.sra
#            => ‘sra_files/SRR7108402.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.7
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.7|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108402 ... done.
# ==> SIZE SRR7108402.sra ... 270296331
# ==> PASV ... done.    ==> RETR SRR7108402.sra ... done.
# Length: 270296331 (258M) (unauthoritative)
#
# 100%[======================================>] 270,296,331 49.8MB/s   in 5.5s
#
# 2019-05-03 12:25:35 (46.9 MB/s) - ‘sra_files/SRR7108402.sra’ saved [270296331]
#
# --2019-05-03 12:25:35--  ftp://ftp-trace.ncbi.nih.gov/sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108403/SRR7108403.sra
#            => ‘sra_files/SRR7108403.sra’
# Resolving ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)... 130.14.250.11
# Connecting to ftp-trace.ncbi.nih.gov (ftp-trace.ncbi.nih.gov)|130.14.250.11|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /sra/sra-instant/reads/ByRun/sra/SRR/SRR710/SRR7108403 ... done.
# ==> SIZE SRR7108403.sra ... 285212666
# ==> PASV ... done.    ==> RETR SRR7108403.sra ... done.
# Length: 285212666 (272M) (unauthoritative)
#
# 100%[======================================>] 285,212,666 45.2MB/s   in 6.7s
#
# 2019-05-03 12:25:42 (40.8 MB/s) - ‘sra_files/SRR7108403.sra’ saved [285212666]

# %% [markdown]
# ### 2. Converting SRA files to FASTQ files

# %% [markdown]
# Here, the downloaded SRA files are converted to FASTQ files. Since the files are **single-end** RNA-seq samples, the flag `--split-3` was removed (compare code with the commented code below it).

# %%
cut -f5 samples.txt | xargs -i sh -c \
'v={}; fastq-dump --outdir fastq/${v} --gzip \
--skip-technical sra_files/${v}.sra'

# cut -f5 samples.txt | xargs -i sh -c \
# 'v={}; fastq-dump --outdir fastq/${v} --gzip \
# --skip-technical --split-3 sra_files/${v}.sra'
# Out:
# Read 11178724 spots for sra_files/SRR7108388.sra
# Written 11178724 spots for sra_files/SRR7108388.sra
# Read 11690279 spots for sra_files/SRR7108389.sra
# Written 11690279 spots for sra_files/SRR7108389.sra
# Read 11417913 spots for sra_files/SRR7108390.sra
# Written 11417913 spots for sra_files/SRR7108390.sra
# Read 10488738 spots for sra_files/SRR7108391.sra
# Written 10488738 spots for sra_files/SRR7108391.sra
# Read 11664932 spots for sra_files/SRR7108392.sra
# Written 11664932 spots for sra_files/SRR7108392.sra
# Read 12283466 spots for sra_files/SRR7108393.sra
# Written 12283466 spots for sra_files/SRR7108393.sra
# Read 13466090 spots for sra_files/SRR7108394.sra
# Written 13466090 spots for sra_files/SRR7108394.sra
# Read 11018251 spots for sra_files/SRR7108395.sra
# Written 11018251 spots for sra_files/SRR7108395.sra
# Read 13132487 spots for sra_files/SRR7108396.sra
# Written 13132487 spots for sra_files/SRR7108396.sra
# Read 11092257 spots for sra_files/SRR7108397.sra
# Written 11092257 spots for sra_files/SRR7108397.sra
# Read 12023368 spots for sra_files/SRR7108398.sra
# Written 12023368 spots for sra_files/SRR7108398.sra
# Read 13714017 spots for sra_files/SRR7108399.sra
# Written 13714017 spots for sra_files/SRR7108399.sra
# Read 12991428 spots for sra_files/SRR7108400.sra
# Written 12991428 spots for sra_files/SRR7108400.sra
# Read 10896059 spots for sra_files/SRR7108401.sra
# Written 10896059 spots for sra_files/SRR7108401.sra
# Read 11416147 spots for sra_files/SRR7108402.sra
# Written 11416147 spots for sra_files/SRR7108402.sra
# Read 12125523 spots for sra_files/SRR7108403.sra
# Written 12125523 spots for sra_files/SRR7108403.sra

# %%
tree
# Out:
# .
# ├── all_samples.txt
# ├── fastq
# │   ├── SRR7108388
# │   │   └── SRR7108388.fastq.gz
# │   ├── SRR7108389
# │   │   └── SRR7108389.fastq.gz
# │   ├── SRR7108390
# │   │   └── SRR7108390.fastq.gz
# │   ├── SRR7108391
# │   │   └── SRR7108391.fastq.gz
# │   ├── SRR7108392
# │   │   └── SRR7108392.fastq.gz
# │   ├── SRR7108393
# │   │   └── SRR7108393.fastq.gz
# │   ├── SRR7108394
# │   │   └── SRR7108394.fastq.gz
# │   ├── SRR7108395
# │   │   └── SRR7108395.fastq.gz
# │   ├── SRR7108396
# │   │   └── SRR7108396.fastq.gz
# │   ├── SRR7108397
# │   │   └── SRR7108397.fastq.gz
# │   ├── SRR7108398
# │   │   └── SRR7108398.fastq.gz
# │   ├── SRR7108399
# │   │   └── SRR7108399.fastq.gz
# │   ├── SRR7108400
# │   │   └── SRR7108400.fastq.gz
# │   ├── SRR7108401
# │   │   └── SRR7108401.fastq.gz
# │   ├── SRR7108402
# │   │   └── SRR7108402.fastq.gz
# │   └── SRR7108403
# │       └── SRR7108403.fastq.gz
# ├── project2.ipynb
# ├── samples.txt
# └── sra_files
#     ├── SRR7108388.sra
#     ├── SRR7108389.sra
#     ├── SRR7108390.sra
#     ├── SRR7108391.sra
#     ├── SRR7108392.sra
#     ├── SRR7108393.sra
#     ├── SRR7108394.sra
#     ├── SRR7108395.sra
#     ├── SRR7108396.sra
#     ├── SRR7108397.sra
#     ├── SRR7108398.sra
#     ├── SRR7108399.sra
#     ├── SRR7108400.sra
#     ├── SRR7108401.sra
#     ├── SRR7108402.sra
#     └── SRR7108403.sra
#
# 18 directories, 35 files

# %% [markdown]
# ### 3. Quality Control of the FASTQ files

# %% [markdown]
# The code below performs the quality control (QC) for all the samples thru the `fastqc` tools (<a href="https://www.bioinformatics.babraham.ac.uk/projects/fastqc/" targ et="_blank">Babraham Institute</a>).
#
# <!-- ([Babraham Institute](https://www.bioinformatics.babraham.ac.uk/projects/fastqc/)). -->

# %%
cut -f5 samples.txt | xargs -i sh -c \
'v={}; mkdir -p fastqc_reports/${v};\
fastqc fastq/${v}/*fastq.gz -o fastqc_reports/${v}'
# Out:
# Started analysis of SRR7108388.fastq.gz
# Approx 5% complete for SRR7108388.fastq.gz
# Approx 10% complete for SRR7108388.fastq.gz
# Approx 15% complete for SRR7108388.fastq.gz
# Approx 20% complete for SRR7108388.fastq.gz
# Approx 25% complete for SRR7108388.fastq.gz
# Approx 30% complete for SRR7108388.fastq.gz
# Approx 35% complete for SRR7108388.fastq.gz
# Approx 40% complete for SRR7108388.fastq.gz
# Approx 45% complete for SRR7108388.fastq.gz
# Approx 50% complete for SRR7108388.fastq.gz
# Approx 55% complete for SRR7108388.fastq.gz
# Approx 60% complete for SRR7108388.fastq.gz
# Approx 65% complete for SRR7108388.fastq.gz
# Approx 70% complete for SRR7108388.fastq.gz
# Approx 75% complete for SRR7108388.fastq.gz
# Approx 80% complete for SRR7108388.fastq.gz
# Approx 85% complete for SRR7108388.fastq.gz
# Approx 90% complete for SRR7108388.fastq.gz
# Approx 95% complete for SRR7108388.fastq.gz
# Analysis complete for SRR7108388.fastq.gz
# Started analysis of SRR7108389.fastq.gz
# Approx 5% complete for SRR7108389.fastq.gz
# Approx 10% complete for SRR7108389.fastq.gz
# Approx 15% complete for SRR7108389.fastq.gz
# Approx 20% complete for SRR7108389.fastq.gz
# Approx 25% complete for SRR7108389.fastq.gz
# Approx 30% complete for SRR7108389.fastq.gz
# Approx 35% complete for SRR7108389.fastq.gz
# Approx 40% complete for SRR7108389.fastq.gz
# Approx 45% complete for SRR7108389.fastq.gz
# Approx 50% complete for SRR7108389.fastq.gz
# Approx 55% complete for SRR7108389.fastq.gz
# Approx 60% complete for SRR7108389.fastq.gz
# Approx 65% complete for SRR7108389.fastq.gz
# Approx 70% complete for SRR7108389.fastq.gz
# Approx 75% complete for SRR7108389.fastq.gz
# Approx 80% complete for SRR7108389.fastq.gz
# Approx 85% complete for SRR7108389.fastq.gz
# Approx 90% complete for SRR7108389.fastq.gz
# Approx 95% complete for SRR7108389.fastq.gz
# Analysis complete for SRR7108389.fastq.gz
# Started analysis of SRR7108390.fastq.gz
# Approx 5% complete for SRR7108390.fastq.gz
# Approx 10% complete for SRR7108390.fastq.gz
# Approx 15% complete for SRR7108390.fastq.gz
# Approx 20% complete for SRR7108390.fastq.gz
# Approx 25% complete for SRR7108390.fastq.gz
# Approx 30% complete for SRR7108390.fastq.gz
# Approx 35% complete for SRR7108390.fastq.gz
# Approx 40% complete for SRR7108390.fastq.gz
# Approx 45% complete for SRR7108390.fastq.gz
# Approx 50% complete for SRR7108390.fastq.gz
# Approx 55% complete for SRR7108390.fastq.gz
# Approx 60% complete for SRR7108390.fastq.gz
# Approx 65% complete for SRR7108390.fastq.gz
# Approx 70% complete for SRR7108390.fastq.gz
# Approx 75% complete for SRR7108390.fastq.gz
# Approx 80% complete for SRR7108390.fastq.gz
# Approx 85% complete for SRR7108390.fastq.gz
# Approx 90% complete for SRR7108390.fastq.gz
# Approx 95% complete for SRR7108390.fastq.gz
# Analysis complete for SRR7108390.fastq.gz
# Started analysis of SRR7108391.fastq.gz
# Approx 5% complete for SRR7108391.fastq.gz
# Approx 10% complete for SRR7108391.fastq.gz
# Approx 15% complete for SRR7108391.fastq.gz
# Approx 20% complete for SRR7108391.fastq.gz
# Approx 25% complete for SRR7108391.fastq.gz
# Approx 30% complete for SRR7108391.fastq.gz
# Approx 35% complete for SRR7108391.fastq.gz
# Approx 40% complete for SRR7108391.fastq.gz
# Approx 45% complete for SRR7108391.fastq.gz
# Approx 50% complete for SRR7108391.fastq.gz
# Approx 55% complete for SRR7108391.fastq.gz
# Approx 60% complete for SRR7108391.fastq.gz
# Approx 65% complete for SRR7108391.fastq.gz
# Approx 70% complete for SRR7108391.fastq.gz
# Approx 75% complete for SRR7108391.fastq.gz
# Approx 80% complete for SRR7108391.fastq.gz
# Approx 85% complete for SRR7108391.fastq.gz
# Approx 90% complete for SRR7108391.fastq.gz
# Approx 95% complete for SRR7108391.fastq.gz
# Analysis complete for SRR7108391.fastq.gz
# Started analysis of SRR7108392.fastq.gz
# Approx 5% complete for SRR7108392.fastq.gz
# Approx 10% complete for SRR7108392.fastq.gz
# Approx 15% complete for SRR7108392.fastq.gz
# Approx 20% complete for SRR7108392.fastq.gz
# Approx 25% complete for SRR7108392.fastq.gz
# Approx 30% complete for SRR7108392.fastq.gz
# Approx 35% complete for SRR7108392.fastq.gz
# Approx 40% complete for SRR7108392.fastq.gz
# Approx 45% complete for SRR7108392.fastq.gz
# Approx 50% complete for SRR7108392.fastq.gz
# Approx 55% complete for SRR7108392.fastq.gz
# Approx 60% complete for SRR7108392.fastq.gz
# Approx 65% complete for SRR7108392.fastq.gz
# Approx 70% complete for SRR7108392.fastq.gz
# Approx 75% complete for SRR7108392.fastq.gz
# Approx 80% complete for SRR7108392.fastq.gz
# Approx 85% complete for SRR7108392.fastq.gz
# Approx 90% complete for SRR7108392.fastq.gz
# Approx 95% complete for SRR7108392.fastq.gz
# Analysis complete for SRR7108392.fastq.gz
# Started analysis of SRR7108393.fastq.gz
# Approx 5% complete for SRR7108393.fastq.gz
# Approx 10% complete for SRR7108393.fastq.gz
# Approx 15% complete for SRR7108393.fastq.gz
# Approx 20% complete for SRR7108393.fastq.gz
# Approx 25% complete for SRR7108393.fastq.gz
# Approx 30% complete for SRR7108393.fastq.gz
# Approx 35% complete for SRR7108393.fastq.gz
# Approx 40% complete for SRR7108393.fastq.gz
# Approx 45% complete for SRR7108393.fastq.gz
# Approx 50% complete for SRR7108393.fastq.gz
# Approx 55% complete for SRR7108393.fastq.gz
# Approx 60% complete for SRR7108393.fastq.gz
# Approx 65% complete for SRR7108393.fastq.gz
# Approx 70% complete for SRR7108393.fastq.gz
# Approx 75% complete for SRR7108393.fastq.gz
# Approx 80% complete for SRR7108393.fastq.gz
# Approx 85% complete for SRR7108393.fastq.gz
# Approx 90% complete for SRR7108393.fastq.gz
# Approx 95% complete for SRR7108393.fastq.gz
# Analysis complete for SRR7108393.fastq.gz
# Started analysis of SRR7108394.fastq.gz
# Approx 5% complete for SRR7108394.fastq.gz
# Approx 10% complete for SRR7108394.fastq.gz
# Approx 15% complete for SRR7108394.fastq.gz
# Approx 20% complete for SRR7108394.fastq.gz
# Approx 25% complete for SRR7108394.fastq.gz
# Approx 30% complete for SRR7108394.fastq.gz
# Approx 35% complete for SRR7108394.fastq.gz
# Approx 40% complete for SRR7108394.fastq.gz
# Approx 45% complete for SRR7108394.fastq.gz
# Approx 50% complete for SRR7108394.fastq.gz
# Approx 55% complete for SRR7108394.fastq.gz
# Approx 60% complete for SRR7108394.fastq.gz
# Approx 65% complete for SRR7108394.fastq.gz
# Approx 70% complete for SRR7108394.fastq.gz
# Approx 75% complete for SRR7108394.fastq.gz
# Approx 80% complete for SRR7108394.fastq.gz
# Approx 85% complete for SRR7108394.fastq.gz
# Approx 90% complete for SRR7108394.fastq.gz
# Approx 95% complete for SRR7108394.fastq.gz
# Analysis complete for SRR7108394.fastq.gz
# Started analysis of SRR7108395.fastq.gz
# Approx 5% complete for SRR7108395.fastq.gz
# Approx 10% complete for SRR7108395.fastq.gz
# Approx 15% complete for SRR7108395.fastq.gz
# Approx 20% complete for SRR7108395.fastq.gz
# Approx 25% complete for SRR7108395.fastq.gz
# Approx 30% complete for SRR7108395.fastq.gz
# Approx 35% complete for SRR7108395.fastq.gz
# Approx 40% complete for SRR7108395.fastq.gz
# Approx 45% complete for SRR7108395.fastq.gz
# Approx 50% complete for SRR7108395.fastq.gz
# Approx 55% complete for SRR7108395.fastq.gz
# Approx 60% complete for SRR7108395.fastq.gz
# Approx 65% complete for SRR7108395.fastq.gz
# Approx 70% complete for SRR7108395.fastq.gz
# Approx 75% complete for SRR7108395.fastq.gz
# Approx 80% complete for SRR7108395.fastq.gz
# Approx 85% complete for SRR7108395.fastq.gz
# Approx 90% complete for SRR7108395.fastq.gz
# Approx 95% complete for SRR7108395.fastq.gz
# Analysis complete for SRR7108395.fastq.gz
# Started analysis of SRR7108396.fastq.gz
# Approx 5% complete for SRR7108396.fastq.gz
# Approx 10% complete for SRR7108396.fastq.gz
# Approx 15% complete for SRR7108396.fastq.gz
# Approx 20% complete for SRR7108396.fastq.gz
# Approx 25% complete for SRR7108396.fastq.gz
# Approx 30% complete for SRR7108396.fastq.gz
# Approx 35% complete for SRR7108396.fastq.gz
# Approx 40% complete for SRR7108396.fastq.gz
# Approx 45% complete for SRR7108396.fastq.gz
# Approx 50% complete for SRR7108396.fastq.gz
# Approx 55% complete for SRR7108396.fastq.gz
# Approx 60% complete for SRR7108396.fastq.gz
# Approx 65% complete for SRR7108396.fastq.gz
# Approx 70% complete for SRR7108396.fastq.gz
# Approx 75% complete for SRR7108396.fastq.gz
# Approx 80% complete for SRR7108396.fastq.gz
# Approx 85% complete for SRR7108396.fastq.gz
# Approx 90% complete for SRR7108396.fastq.gz
# Approx 95% complete for SRR7108396.fastq.gz
# Analysis complete for SRR7108396.fastq.gz
# Started analysis of SRR7108397.fastq.gz
# Approx 5% complete for SRR7108397.fastq.gz
# Approx 10% complete for SRR7108397.fastq.gz
# Approx 15% complete for SRR7108397.fastq.gz
# Approx 20% complete for SRR7108397.fastq.gz
# Approx 25% complete for SRR7108397.fastq.gz
# Approx 30% complete for SRR7108397.fastq.gz
# Approx 35% complete for SRR7108397.fastq.gz
# Approx 40% complete for SRR7108397.fastq.gz
# Approx 45% complete for SRR7108397.fastq.gz
# Approx 50% complete for SRR7108397.fastq.gz
# Approx 55% complete for SRR7108397.fastq.gz
# Approx 60% complete for SRR7108397.fastq.gz
# Approx 65% complete for SRR7108397.fastq.gz
# Approx 70% complete for SRR7108397.fastq.gz
# Approx 75% complete for SRR7108397.fastq.gz
# Approx 80% complete for SRR7108397.fastq.gz
# Approx 85% complete for SRR7108397.fastq.gz
# Approx 90% complete for SRR7108397.fastq.gz
# Approx 95% complete for SRR7108397.fastq.gz
# Analysis complete for SRR7108397.fastq.gz
# Started analysis of SRR7108398.fastq.gz
# Approx 5% complete for SRR7108398.fastq.gz
# Approx 10% complete for SRR7108398.fastq.gz
# Approx 15% complete for SRR7108398.fastq.gz
# Approx 20% complete for SRR7108398.fastq.gz
# Approx 25% complete for SRR7108398.fastq.gz
# Approx 30% complete for SRR7108398.fastq.gz
# Approx 35% complete for SRR7108398.fastq.gz
# Approx 40% complete for SRR7108398.fastq.gz
# Approx 45% complete for SRR7108398.fastq.gz
# Approx 50% complete for SRR7108398.fastq.gz
# Approx 55% complete for SRR7108398.fastq.gz
# Approx 60% complete for SRR7108398.fastq.gz
# Approx 65% complete for SRR7108398.fastq.gz
# Approx 70% complete for SRR7108398.fastq.gz
# Approx 75% complete for SRR7108398.fastq.gz
# Approx 80% complete for SRR7108398.fastq.gz
# Approx 85% complete for SRR7108398.fastq.gz
# Approx 90% complete for SRR7108398.fastq.gz
# Approx 95% complete for SRR7108398.fastq.gz
# Analysis complete for SRR7108398.fastq.gz
# Started analysis of SRR7108399.fastq.gz
# Approx 5% complete for SRR7108399.fastq.gz
# Approx 10% complete for SRR7108399.fastq.gz
# Approx 15% complete for SRR7108399.fastq.gz
# Approx 20% complete for SRR7108399.fastq.gz
# Approx 25% complete for SRR7108399.fastq.gz
# Approx 30% complete for SRR7108399.fastq.gz
# Approx 35% complete for SRR7108399.fastq.gz
# Approx 40% complete for SRR7108399.fastq.gz
# Approx 45% complete for SRR7108399.fastq.gz
# Approx 50% complete for SRR7108399.fastq.gz
# Approx 55% complete for SRR7108399.fastq.gz
# Approx 60% complete for SRR7108399.fastq.gz
# Approx 65% complete for SRR7108399.fastq.gz
# Approx 70% complete for SRR7108399.fastq.gz
# Approx 75% complete for SRR7108399.fastq.gz
# Approx 80% complete for SRR7108399.fastq.gz
# Approx 85% complete for SRR7108399.fastq.gz
# Approx 90% complete for SRR7108399.fastq.gz
# Approx 95% complete for SRR7108399.fastq.gz
# Analysis complete for SRR7108399.fastq.gz
# Started analysis of SRR7108400.fastq.gz
# Approx 5% complete for SRR7108400.fastq.gz
# Approx 10% complete for SRR7108400.fastq.gz
# Approx 15% complete for SRR7108400.fastq.gz
# Approx 20% complete for SRR7108400.fastq.gz
# Approx 25% complete for SRR7108400.fastq.gz
# Approx 30% complete for SRR7108400.fastq.gz
# Approx 35% complete for SRR7108400.fastq.gz
# Approx 40% complete for SRR7108400.fastq.gz
# Approx 45% complete for SRR7108400.fastq.gz
# Approx 50% complete for SRR7108400.fastq.gz
# Approx 55% complete for SRR7108400.fastq.gz
# Approx 60% complete for SRR7108400.fastq.gz
# Approx 65% complete for SRR7108400.fastq.gz
# Approx 70% complete for SRR7108400.fastq.gz
# Approx 75% complete for SRR7108400.fastq.gz
# Approx 80% complete for SRR7108400.fastq.gz
# Approx 85% complete for SRR7108400.fastq.gz
# Approx 90% complete for SRR7108400.fastq.gz
# Approx 95% complete for SRR7108400.fastq.gz
# Analysis complete for SRR7108400.fastq.gz
# Started analysis of SRR7108401.fastq.gz
# Approx 5% complete for SRR7108401.fastq.gz
# Approx 10% complete for SRR7108401.fastq.gz
# Approx 15% complete for SRR7108401.fastq.gz
# Approx 20% complete for SRR7108401.fastq.gz
# Approx 25% complete for SRR7108401.fastq.gz
# Approx 30% complete for SRR7108401.fastq.gz
# Approx 35% complete for SRR7108401.fastq.gz
# Approx 40% complete for SRR7108401.fastq.gz
# Approx 45% complete for SRR7108401.fastq.gz
# Approx 50% complete for SRR7108401.fastq.gz
# Approx 55% complete for SRR7108401.fastq.gz
# Approx 60% complete for SRR7108401.fastq.gz
# Approx 65% complete for SRR7108401.fastq.gz
# Approx 70% complete for SRR7108401.fastq.gz
# Approx 75% complete for SRR7108401.fastq.gz
# Approx 80% complete for SRR7108401.fastq.gz
# Approx 85% complete for SRR7108401.fastq.gz
# Approx 90% complete for SRR7108401.fastq.gz
# Approx 95% complete for SRR7108401.fastq.gz
# Analysis complete for SRR7108401.fastq.gz
# Started analysis of SRR7108402.fastq.gz
# Approx 5% complete for SRR7108402.fastq.gz
# Approx 10% complete for SRR7108402.fastq.gz
# Approx 15% complete for SRR7108402.fastq.gz
# Approx 20% complete for SRR7108402.fastq.gz
# Approx 25% complete for SRR7108402.fastq.gz
# Approx 30% complete for SRR7108402.fastq.gz
# Approx 35% complete for SRR7108402.fastq.gz
# Approx 40% complete for SRR7108402.fastq.gz
# Approx 45% complete for SRR7108402.fastq.gz
# Approx 50% complete for SRR7108402.fastq.gz
# Approx 55% complete for SRR7108402.fastq.gz
# Approx 60% complete for SRR7108402.fastq.gz
# Approx 65% complete for SRR7108402.fastq.gz
# Approx 70% complete for SRR7108402.fastq.gz
# Approx 75% complete for SRR7108402.fastq.gz
# Approx 80% complete for SRR7108402.fastq.gz
# Approx 85% complete for SRR7108402.fastq.gz
# Approx 90% complete for SRR7108402.fastq.gz
# Approx 95% complete for SRR7108402.fastq.gz
# Analysis complete for SRR7108402.fastq.gz
# Started analysis of SRR7108403.fastq.gz
# Approx 5% complete for SRR7108403.fastq.gz
# Approx 10% complete for SRR7108403.fastq.gz
# Approx 15% complete for SRR7108403.fastq.gz
# Approx 20% complete for SRR7108403.fastq.gz
# Approx 25% complete for SRR7108403.fastq.gz
# Approx 30% complete for SRR7108403.fastq.gz
# Approx 35% complete for SRR7108403.fastq.gz
# Approx 40% complete for SRR7108403.fastq.gz
# Approx 45% complete for SRR7108403.fastq.gz
# Approx 50% complete for SRR7108403.fastq.gz
# Approx 55% complete for SRR7108403.fastq.gz
# Approx 60% complete for SRR7108403.fastq.gz
# Approx 65% complete for SRR7108403.fastq.gz
# Approx 70% complete for SRR7108403.fastq.gz
# Approx 75% complete for SRR7108403.fastq.gz
# Approx 80% complete for SRR7108403.fastq.gz
# Approx 85% complete for SRR7108403.fastq.gz
# Approx 90% complete for SRR7108403.fastq.gz
# Approx 95% complete for SRR7108403.fastq.gz
# Analysis complete for SRR7108403.fastq.gz

# %% [markdown]
# QC summarization is done below thru `multiqc`. The code combines the reports in `fastqc_reports` from multiple directories (`--dirs`) and outputs (`-o`), and places them into a new folder, `multiQC_report`.

# %%
multiqc fastqc_reports --dirs -o multiQC_report/
# Out:
# [WARNING]         multiqc : MultiQC Version v1.7 now available!
# [INFO   ]         multiqc : This is MultiQC v1.6
# [INFO   ]         multiqc : Template    : default
# [INFO   ]         multiqc : Prepending directory to sample names
# [INFO   ]         multiqc : Searching 'fastqc_reports'
# [INFO   ]          fastqc : Found 16 reports
# [INFO   ]         multiqc : Compressing plot data
# [INFO   ]         multiqc : Report      : multiQC_report/multiqc_report.html
# [INFO   ]         multiqc : Data        : multiQC_report/multiqc_data
# [INFO   ]         multiqc : MultiQC complete

# %% [markdown]
# The code below runs the combined QC report summary for all samples.

# %%
xdg-open multiQC_report/multiqc_report.html

# %% [markdown]
# ### 4. Read Alignment

# %% [markdown]
# #### 4.1. Reference genomes and annotation

# %%
wget -P reference \
ftp://ftp.ensembl.org/pub/release-96/fasta/homo_sapiens/dna/\
Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz
# Out:
# Created new window in existing browser session.
# --2019-05-03 13:35:11--  ftp://ftp.ensembl.org/pub/release-96/fasta/homo_sapiens/dna/Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz
#            => ‘reference/Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz’
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.8
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.8|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/release-96/fasta/homo_sapiens/dna ... done.
# ==> SIZE Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz ... 881211416
# ==> PASV ... done.    ==> RETR Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz ... done.
# Length: 881211416 (840M) (unauthoritative)
#
# 100%[======================================>] 881,211,416 5.36MB/s   in 2m 40s
#
# 2019-05-03 13:37:53 (5.27 MB/s) - ‘reference/Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz’ saved [881211416]

# %%
# Decompress genome sequence file and rename it
gzip -dk \
< reference/Homo_sapiens.GRCh38.dna.primary_assembly.fa.gz \
> reference/human_genome.fa

# %%
wget -P annotation \
ftp://ftp.ensembl.org/pub/release-96/gtf/homo_sapiens/\
Homo_sapiens.GRCh38.96.gtf.gz
# Out:
# --2019-05-03 13:38:55--  ftp://ftp.ensembl.org/pub/release-96/gtf/homo_sapiens/Homo_sapiens.GRCh38.96.gtf.gz
#            => ‘annotation/Homo_sapiens.GRCh38.96.gtf.gz’
# Resolving ftp.ensembl.org (ftp.ensembl.org)... 193.62.193.8
# Connecting to ftp.ensembl.org (ftp.ensembl.org)|193.62.193.8|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /pub/release-96/gtf/homo_sapiens ... done.
# ==> SIZE Homo_sapiens.GRCh38.96.gtf.gz ... 44562540
# ==> PASV ... done.    ==> RETR Homo_sapiens.GRCh38.96.gtf.gz ... done.
# Length: 44562540 (42M) (unauthoritative)
#
# 100%[======================================>] 44,562,540  10.8MB/s   in 4.6s
#
# 2019-05-03 13:39:02 (9.18 MB/s) - ‘annotation/Homo_sapiens.GRCh38.96.gtf.gz’ saved [44562540]

# %%
# Decompress
gzip -dk \
< annotation/Homo_sapiens.GRCh38.96.gtf.gz \
> annotation/gene_annotation.gtf

# %% [markdown]
# #### 4.2. Aligning reads using STAR

# %% [markdown]
# ##### 4.2.1. Generate genome index

# %%
mkdir -p STARindex

# %%
# Run STAR in "genomeGenerate" mode with 10 threads
# Feel free to change the 'runThreadN' parameter
# depending on the number of cores available on your computer

STAR --runThreadN 8 \
--runMode genomeGenerate \
--genomeDir STARindex \
--genomeFastaFiles reference/human_genome.fa \
--genomeChrBinNbits 15 \
--sjdbGTFfile annotation/gene_annotation.gtf \
--sjdbOverhang 49
# Out:
# May 03 14:33:29 ..... Started STAR run
# May 03 14:33:29 ... Starting to generate Genome files
# May 03 14:34:26 ... starting to sort  Suffix Array. This may take a long time...
# May 03 14:34:43 ... sorting Suffix Array chunks and saving them to disk...
# May 03 14:52:34 ... loading chunks from disk, packing SA...
# May 03 14:57:00 ... Finished generating suffix array
# May 03 14:57:00 ... starting to generate Suffix Array index...
# May 03 15:09:16 ..... Processing annotations GTF
# May 03 15:09:38 ..... Inserting junctions into the genome indices
# May 03 15:11:52 ... writing Genome to disk ...
# May 03 15:12:17 ... writing Suffix Array to disk ...
# May 03 15:15:19 ... writing SAindex to disk
# May 03 15:15:31 ..... Finished successfully

# %% [markdown]
# ##### 4.2.2. Alignment

# %%
mkdir -p alignment_STAR

# %%
# execute STAR in the runMode "alignReads"
cut -f5 samples.txt | xargs -i sh -c \
'v={}; STAR --genomeDir STARindex \
--readFilesIn fastq/${v}/*fastq.gz \
--readFilesCommand zcat \
--outFileNamePrefix alignment_STAR/${v} \
--outFilterMultimapNmax 1 \
--outReadsUnmapped Fastx \
--outSAMtype BAM SortedByCoordinate \
--twopassMode Basic \
--runThreadN 8'
# Out:
# May 03 15:15:50 ..... Started STAR run
# May 03 15:15:50 ..... Loading genome
# May 03 15:18:04 ..... Started 1st pass mapping
# May 03 15:19:17 ..... Finished 1st pass mapping
# May 03 15:19:18 ..... Inserting junctions into the genome indices
# May 03 15:20:33 ..... Started mapping
# May 03 15:21:52 ..... Started sorting BAM
# May 03 15:22:10 ..... Finished successfully
# May 03 15:22:10 ..... Started STAR run
# May 03 15:22:10 ..... Loading genome
# May 03 15:24:25 ..... Started 1st pass mapping
# May 03 15:25:41 ..... Finished 1st pass mapping
# May 03 15:25:42 ..... Inserting junctions into the genome indices
# May 03 15:26:57 ..... Started mapping
# May 03 15:28:19 ..... Started sorting BAM
# May 03 15:28:38 ..... Finished successfully
# May 03 15:28:38 ..... Started STAR run
# May 03 15:28:38 ..... Loading genome
# May 03 15:30:54 ..... Started 1st pass mapping
# May 03 15:32:07 ..... Finished 1st pass mapping
# May 03 15:32:08 ..... Inserting junctions into the genome indices
# May 03 15:33:21 ..... Started mapping
# May 03 15:34:42 ..... Started sorting BAM
# May 03 15:35:00 ..... Finished successfully
# May 03 15:35:00 ..... Started STAR run
# May 03 15:35:00 ..... Loading genome
# May 03 15:37:14 ..... Started 1st pass mapping
# May 03 15:38:23 ..... Finished 1st pass mapping
# May 03 15:38:24 ..... Inserting junctions into the genome indices
# May 03 15:39:37 ..... Started mapping
# May 03 15:40:52 ..... Started sorting BAM
# May 03 15:41:10 ..... Finished successfully
# May 03 15:41:11 ..... Started STAR run
# May 03 15:41:11 ..... Loading genome
# May 03 15:43:26 ..... Started 1st pass mapping
# May 03 15:44:40 ..... Finished 1st pass mapping
# May 03 15:44:41 ..... Inserting junctions into the genome indices
# May 03 15:45:53 ..... Started mapping
# May 03 15:47:16 ..... Started sorting BAM
# May 03 15:47:38 ..... Finished successfully
# May 03 15:47:39 ..... Started STAR run
# May 03 15:47:39 ..... Loading genome
# May 03 15:49:52 ..... Started 1st pass mapping
# May 03 15:51:11 ..... Finished 1st pass mapping
# May 03 15:51:12 ..... Inserting junctions into the genome indices
# May 03 15:52:25 ..... Started mapping
# May 03 15:53:51 ..... Started sorting BAM
# May 03 15:54:09 ..... Finished successfully
# May 03 15:54:09 ..... Started STAR run
# May 03 15:54:09 ..... Loading genome
# May 03 15:56:23 ..... Started 1st pass mapping
# May 03 15:57:49 ..... Finished 1st pass mapping
# May 03 15:57:51 ..... Inserting junctions into the genome indices
# May 03 15:59:05 ..... Started mapping
# May 03 16:00:40 ..... Started sorting BAM
# May 03 16:01:06 ..... Finished successfully
# May 03 16:01:07 ..... Started STAR run
# May 03 16:01:07 ..... Loading genome
# May 03 16:03:21 ..... Started 1st pass mapping
# May 03 16:04:33 ..... Finished 1st pass mapping
# May 03 16:04:35 ..... Inserting junctions into the genome indices
# May 03 16:05:47 ..... Started mapping
# May 03 16:07:04 ..... Started sorting BAM
# May 03 16:07:25 ..... Finished successfully
# May 03 16:07:26 ..... Started STAR run
# May 03 16:07:26 ..... Loading genome
# May 03 16:09:39 ..... Started 1st pass mapping
# May 03 16:11:03 ..... Finished 1st pass mapping
# May 03 16:11:04 ..... Inserting junctions into the genome indices
# May 03 16:12:18 ..... Started mapping
# May 03 16:13:49 ..... Started sorting BAM
# May 03 16:14:14 ..... Finished successfully
# May 03 16:14:14 ..... Started STAR run
# May 03 16:14:14 ..... Loading genome
# May 03 16:16:28 ..... Started 1st pass mapping
# May 03 16:17:40 ..... Finished 1st pass mapping
# May 03 16:17:42 ..... Inserting junctions into the genome indices
# May 03 16:18:54 ..... Started mapping
# May 03 16:20:11 ..... Started sorting BAM
# May 03 16:20:31 ..... Finished successfully
# May 03 16:20:32 ..... Started STAR run
# May 03 16:20:32 ..... Loading genome
# May 03 16:22:46 ..... Started 1st pass mapping
# May 03 16:24:04 ..... Finished 1st pass mapping
# May 03 16:24:06 ..... Inserting junctions into the genome indices
# May 03 16:25:19 ..... Started mapping
# May 03 16:26:46 ..... Started sorting BAM
# May 03 16:27:06 ..... Finished successfully
# May 03 16:27:06 ..... Started STAR run
# May 03 16:27:06 ..... Loading genome
# May 03 16:29:23 ..... Started 1st pass mapping
# May 03 16:30:52 ..... Finished 1st pass mapping
# May 03 16:30:53 ..... Inserting junctions into the genome indices
# May 03 16:32:09 ..... Started mapping
# May 03 16:33:46 ..... Started sorting BAM
# May 03 16:34:06 ..... Finished successfully
# May 03 16:34:07 ..... Started STAR run
# May 03 16:34:07 ..... Loading genome
# May 03 16:36:22 ..... Started 1st pass mapping
# May 03 16:37:44 ..... Finished 1st pass mapping
# May 03 16:37:45 ..... Inserting junctions into the genome indices
# May 03 16:39:00 ..... Started mapping
# May 03 16:40:33 ..... Started sorting BAM
# May 03 16:40:53 ..... Finished successfully
# May 03 16:40:53 ..... Started STAR run
# May 03 16:40:53 ..... Loading genome
# May 03 16:43:08 ..... Started 1st pass mapping
# May 03 16:44:18 ..... Finished 1st pass mapping
# May 03 16:44:19 ..... Inserting junctions into the genome indices
# May 03 16:45:32 ..... Started mapping
# May 03 16:46:48 ..... Started sorting BAM
# May 03 16:47:07 ..... Finished successfully
# May 03 16:47:08 ..... Started STAR run
# May 03 16:47:08 ..... Loading genome
# May 03 16:49:23 ..... Started 1st pass mapping
# May 03 16:50:39 ..... Finished 1st pass mapping
# May 03 16:50:40 ..... Inserting junctions into the genome indices
# May 03 16:51:54 ..... Started mapping
# May 03 16:53:17 ..... Started sorting BAM
# May 03 16:53:40 ..... Finished successfully
# May 03 16:53:40 ..... Started STAR run
# May 03 16:53:40 ..... Loading genome
# May 03 16:55:55 ..... Started 1st pass mapping
# May 03 16:57:15 ..... Finished 1st pass mapping
# May 03 16:57:16 ..... Inserting junctions into the genome indices
# May 03 16:58:29 ..... Started mapping
# May 03 16:59:58 ..... Started sorting BAM
# May 03 17:00:17 ..... Finished successfully

# %% [markdown]
# ##### 4.2.3. BAM file indexing

# %% [markdown]
# BAM file indexing allows for downstream applications like Integrative Genomics Viewer (IVG) to access the BAM files (thru corresponding .BAM.BAI files) without having to load them into memory.

# %%
for i in alignment_STAR/*; do
    if [ "${i}" != "${i%.bam}" ];then
        samtools index ${i}
    fi
done

# %% [markdown]
# #### 4.3. Read alignment assessment

# %% [markdown]
# This checks the alignment process.

# %%
for i in alignment_STAR/*; do
    if [ "${i}" != "${i%.bam}" ];then
        echo ${i:15:10}
        samtools flagstat ${i}
        echo '############################################################'
    fi
done
# Out:
# SRR7108388
# 8981757 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 8981757 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108389
# 9395707 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 9395707 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108390
# 9142611 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 9142611 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108391
# 8240328 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 8240328 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108392
# 9222057 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 9222057 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108393
# 9582820 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 9582820 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108394
# 10850498 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 10850498 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108395
# 8848325 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 8848325 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108396
# 10751555 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 10751555 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108397
# 9118221 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 9118221 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108398
# 9875251 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 9875251 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108399
# 11156245 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 11156245 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108400
# 10432484 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 10432484 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108401
# 8702003 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 8702003 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108402
# 8946711 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 8946711 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################
# SRR7108403
# 9568146 + 0 in total (QC-passed reads + QC-failed reads)
# 0 + 0 secondary
# 0 + 0 supplimentary
# 0 + 0 duplicates
# 9568146 + 0 mapped (100.00%:-nan%)
# 0 + 0 paired in sequencing
# 0 + 0 read1
# 0 + 0 read2
# 0 + 0 properly paired (-nan%:-nan%)
# 0 + 0 with itself and mate mapped
# 0 + 0 singletons (-nan%:-nan%)
# 0 + 0 with mate mapped to a different chr
# 0 + 0 with mate mapped to a different chr (mapQ>=5)
# ############################################################

# %% [markdown]
# The code below is to check/inspect the final log (`final.out`) file generated by STAR.

# %%
for i in alignment_STAR/*; do
    if [ "${i}" != "${i%.final.out}" ];then
        echo ${i:15:10}
        cat ${i}
        echo
        echo '############################################################'
        echo
    fi
done
# Out:
# SRR7108388
#                                  Started job on |	May 03 15:15:50
#                              Started mapping on |	May 03 15:20:33
#                                     Finished on |	May 03 15:22:10
#        Mapping speed, Million of reads per hour |	414.88
#
#                           Number of input reads |	11178724
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	8981757
#                         Uniquely mapped reads % |	80.35%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1571600
#             Number of splices: Annotated (sjdb) |	1570032
#                        Number of splices: GT/AG |	1557552
#                        Number of splices: GC/AG |	11026
#                        Number of splices: AT/AC |	1306
#                Number of splices: Non-canonical |	1716
#                       Mismatch rate per base, % |	0.13%
#                          Deletion rate per base |	0.00%
#                         Deletion average length |	1.39
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.22
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2127193
#              % of reads mapped to too many loci |	19.03%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.51%
#                      % of reads unmapped: other |	0.11%
#
# ############################################################
#
# SRR7108389
#                                  Started job on |	May 03 15:22:10
#                              Started mapping on |	May 03 15:26:57
#                                     Finished on |	May 03 15:28:38
#        Mapping speed, Million of reads per hour |	416.68
#
#                           Number of input reads |	11690279
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	9395707
#                         Uniquely mapped reads % |	80.37%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1649563
#             Number of splices: Annotated (sjdb) |	1647916
#                        Number of splices: GT/AG |	1634910
#                        Number of splices: GC/AG |	11540
#                        Number of splices: AT/AC |	1334
#                Number of splices: Non-canonical |	1779
#                       Mismatch rate per base, % |	0.13%
#                          Deletion rate per base |	0.00%
#                         Deletion average length |	1.39
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.23
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2230574
#              % of reads mapped to too many loci |	19.08%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.43%
#                      % of reads unmapped: other |	0.12%
#
# ############################################################
#
# SRR7108390
#                                  Started job on |	May 03 15:28:38
#                              Started mapping on |	May 03 15:33:21
#                                     Finished on |	May 03 15:35:00
#        Mapping speed, Million of reads per hour |	415.20
#
#                           Number of input reads |	11417913
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	9142611
#                         Uniquely mapped reads % |	80.07%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1599371
#             Number of splices: Annotated (sjdb) |	1597878
#                        Number of splices: GT/AG |	1585303
#                        Number of splices: GC/AG |	10961
#                        Number of splices: AT/AC |	1356
#                Number of splices: Non-canonical |	1751
#                       Mismatch rate per base, % |	0.13%
#                          Deletion rate per base |	0.00%
#                         Deletion average length |	1.39
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.23
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2205037
#              % of reads mapped to too many loci |	19.31%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.50%
#                      % of reads unmapped: other |	0.11%
#
# ############################################################
#
# SRR7108391
#                                  Started job on |	May 03 15:35:00
#                              Started mapping on |	May 03 15:39:37
#                                     Finished on |	May 03 15:41:10
#        Mapping speed, Million of reads per hour |	406.02
#
#                           Number of input reads |	10488738
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	8240328
#                         Uniquely mapped reads % |	78.56%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1439238
#             Number of splices: Annotated (sjdb) |	1437881
#                        Number of splices: GT/AG |	1426444
#                        Number of splices: GC/AG |	10071
#                        Number of splices: AT/AC |	1168
#                Number of splices: Non-canonical |	1555
#                       Mismatch rate per base, % |	0.13%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.39
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.21
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2059623
#              % of reads mapped to too many loci |	19.64%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	1.69%
#                      % of reads unmapped: other |	0.11%
#
# ############################################################
#
# SRR7108392
#                                  Started job on |	May 03 15:41:11
#                              Started mapping on |	May 03 15:45:53
#                                     Finished on |	May 03 15:47:38
#        Mapping speed, Million of reads per hour |	399.94
#
#                           Number of input reads |	11664932
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	9222057
#                         Uniquely mapped reads % |	79.06%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1617437
#             Number of splices: Annotated (sjdb) |	1615698
#                        Number of splices: GT/AG |	1602619
#                        Number of splices: GC/AG |	11541
#                        Number of splices: AT/AC |	1202
#                Number of splices: Non-canonical |	2075
#                       Mismatch rate per base, % |	0.14%
#                          Deletion rate per base |	0.00%
#                         Deletion average length |	1.37
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.23
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2380413
#              % of reads mapped to too many loci |	20.41%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.45%
#                      % of reads unmapped: other |	0.09%
#
# ############################################################
#
# SRR7108393
#                                  Started job on |	May 03 15:47:39
#                              Started mapping on |	May 03 15:52:25
#                                     Finished on |	May 03 15:54:09
#        Mapping speed, Million of reads per hour |	425.20
#
#                           Number of input reads |	12283466
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	9582820
#                         Uniquely mapped reads % |	78.01%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1664608
#             Number of splices: Annotated (sjdb) |	1662878
#                        Number of splices: GT/AG |	1649411
#                        Number of splices: GC/AG |	11874
#                        Number of splices: AT/AC |	1110
#                Number of splices: Non-canonical |	2213
#                       Mismatch rate per base, % |	0.14%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.36
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.25
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2607233
#              % of reads mapped to too many loci |	21.23%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.68%
#                      % of reads unmapped: other |	0.08%
#
# ############################################################
#
# SRR7108394
#                                  Started job on |	May 03 15:54:09
#                              Started mapping on |	May 03 15:59:05
#                                     Finished on |	May 03 16:01:06
#        Mapping speed, Million of reads per hour |	400.64
#
#                           Number of input reads |	13466090
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	10850498
#                         Uniquely mapped reads % |	80.58%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1840588
#             Number of splices: Annotated (sjdb) |	1838591
#                        Number of splices: GT/AG |	1823703
#                        Number of splices: GC/AG |	13084
#                        Number of splices: AT/AC |	1447
#                Number of splices: Non-canonical |	2354
#                       Mismatch rate per base, % |	0.14%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.39
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.23
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2525108
#              % of reads mapped to too many loci |	18.75%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.57%
#                      % of reads unmapped: other |	0.11%
#
# ############################################################
#
# SRR7108395
#                                  Started job on |	May 03 16:01:07
#                              Started mapping on |	May 03 16:05:47
#                                     Finished on |	May 03 16:07:25
#        Mapping speed, Million of reads per hour |	404.75
#
#                           Number of input reads |	11018251
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	8848325
#                         Uniquely mapped reads % |	80.31%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1512160
#             Number of splices: Annotated (sjdb) |	1510539
#                        Number of splices: GT/AG |	1498155
#                        Number of splices: GC/AG |	11090
#                        Number of splices: AT/AC |	1061
#                Number of splices: Non-canonical |	1854
#                       Mismatch rate per base, % |	0.14%
#                          Deletion rate per base |	0.00%
#                         Deletion average length |	1.39
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.23
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2104362
#              % of reads mapped to too many loci |	19.10%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.50%
#                      % of reads unmapped: other |	0.09%
#
# ############################################################
#
# SRR7108396
#                                  Started job on |	May 03 16:07:26
#                              Started mapping on |	May 03 16:12:18
#                                     Finished on |	May 03 16:14:14
#        Mapping speed, Million of reads per hour |	407.56
#
#                           Number of input reads |	13132487
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	10751555
#                         Uniquely mapped reads % |	81.87%
#                           Average mapped length |	49.90
#                        Number of splices: Total |	1866996
#             Number of splices: Annotated (sjdb) |	1865118
#                        Number of splices: GT/AG |	1849926
#                        Number of splices: GC/AG |	13695
#                        Number of splices: AT/AC |	1719
#                Number of splices: Non-canonical |	1656
#                       Mismatch rate per base, % |	0.13%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.38
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.20
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2297053
#              % of reads mapped to too many loci |	17.49%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.48%
#                      % of reads unmapped: other |	0.16%
#
# ############################################################
#
# SRR7108397
#                                  Started job on |	May 03 16:14:14
#                              Started mapping on |	May 03 16:18:54
#                                     Finished on |	May 03 16:20:31
#        Mapping speed, Million of reads per hour |	411.67
#
#                           Number of input reads |	11092257
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	9118221
#                         Uniquely mapped reads % |	82.20%
#                           Average mapped length |	49.90
#                        Number of splices: Total |	1560754
#             Number of splices: Annotated (sjdb) |	1559080
#                        Number of splices: GT/AG |	1546267
#                        Number of splices: GC/AG |	11486
#                        Number of splices: AT/AC |	1524
#                Number of splices: Non-canonical |	1477
#                       Mismatch rate per base, % |	0.13%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.39
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.21
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	1910427
#              % of reads mapped to too many loci |	17.22%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.41%
#                      % of reads unmapped: other |	0.17%
#
# ############################################################
#
# SRR7108398
#                                  Started job on |	May 03 16:20:32
#                              Started mapping on |	May 03 16:25:19
#                                     Finished on |	May 03 16:27:06
#        Mapping speed, Million of reads per hour |	404.52
#
#                           Number of input reads |	12023368
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	9875251
#                         Uniquely mapped reads % |	82.13%
#                           Average mapped length |	49.90
#                        Number of splices: Total |	1712407
#             Number of splices: Annotated (sjdb) |	1710583
#                        Number of splices: GT/AG |	1696534
#                        Number of splices: GC/AG |	12676
#                        Number of splices: AT/AC |	1591
#                Number of splices: Non-canonical |	1606
#                       Mismatch rate per base, % |	0.13%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.39
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.21
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2079304
#              % of reads mapped to too many loci |	17.29%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.40%
#                      % of reads unmapped: other |	0.17%
#
# ############################################################
#
# SRR7108399
#                                  Started job on |	May 03 16:27:06
#                              Started mapping on |	May 03 16:32:09
#                                     Finished on |	May 03 16:34:06
#        Mapping speed, Million of reads per hour |	421.97
#
#                           Number of input reads |	13714017
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	11156245
#                         Uniquely mapped reads % |	81.35%
#                           Average mapped length |	49.90
#                        Number of splices: Total |	1944443
#             Number of splices: Annotated (sjdb) |	1942477
#                        Number of splices: GT/AG |	1926644
#                        Number of splices: GC/AG |	14222
#                        Number of splices: AT/AC |	1810
#                Number of splices: Non-canonical |	1767
#                       Mismatch rate per base, % |	0.13%
#                          Deletion rate per base |	0.00%
#                         Deletion average length |	1.38
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.21
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2476874
#              % of reads mapped to too many loci |	18.06%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.44%
#                      % of reads unmapped: other |	0.15%
#
# ############################################################
#
# SRR7108400
#                                  Started job on |	May 03 16:34:07
#                              Started mapping on |	May 03 16:39:00
#                                     Finished on |	May 03 16:40:53
#        Mapping speed, Million of reads per hour |	413.89
#
#                           Number of input reads |	12991428
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	10432484
#                         Uniquely mapped reads % |	80.30%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1751511
#             Number of splices: Annotated (sjdb) |	1749085
#                        Number of splices: GT/AG |	1733383
#                        Number of splices: GC/AG |	14674
#                        Number of splices: AT/AC |	1414
#                Number of splices: Non-canonical |	2040
#                       Mismatch rate per base, % |	0.14%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.35
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.20
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2469085
#              % of reads mapped to too many loci |	19.01%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.56%
#                      % of reads unmapped: other |	0.13%
#
# ############################################################
#
# SRR7108401
#                                  Started job on |	May 03 16:40:53
#                              Started mapping on |	May 03 16:45:32
#                                     Finished on |	May 03 16:47:07
#        Mapping speed, Million of reads per hour |	412.90
#
#                           Number of input reads |	10896059
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	8702003
#                         Uniquely mapped reads % |	79.86%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1489541
#             Number of splices: Annotated (sjdb) |	1487135
#                        Number of splices: GT/AG |	1473636
#                        Number of splices: GC/AG |	12709
#                        Number of splices: AT/AC |	1142
#                Number of splices: Non-canonical |	2054
#                       Mismatch rate per base, % |	0.14%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.35
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.23
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2141187
#              % of reads mapped to too many loci |	19.65%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.37%
#                      % of reads unmapped: other |	0.12%
#
# ############################################################
#
# SRR7108402
#                                  Started job on |	May 03 16:47:08
#                              Started mapping on |	May 03 16:51:54
#                                     Finished on |	May 03 16:53:40
#        Mapping speed, Million of reads per hour |	387.72
#
#                           Number of input reads |	11416147
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	8946711
#                         Uniquely mapped reads % |	78.37%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1529778
#             Number of splices: Annotated (sjdb) |	1527162
#                        Number of splices: GT/AG |	1513313
#                        Number of splices: GC/AG |	13059
#                        Number of splices: AT/AC |	1195
#                Number of splices: Non-canonical |	2211
#                       Mismatch rate per base, % |	0.14%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.34
#                         Insertion rate per base |	0.00%
#                        Insertion average length |	1.22
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2390803
#              % of reads mapped to too many loci |	20.94%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.55%
#                      % of reads unmapped: other |	0.14%
#
# ############################################################
#
# SRR7108403
#                                  Started job on |	May 03 16:53:40
#                              Started mapping on |	May 03 16:58:29
#                                     Finished on |	May 03 17:00:17
#        Mapping speed, Million of reads per hour |	404.18
#
#                           Number of input reads |	12125523
#                       Average input read length |	50
#                                     UNIQUE READS:
#                    Uniquely mapped reads number |	9568146
#                         Uniquely mapped reads % |	78.91%
#                           Average mapped length |	49.89
#                        Number of splices: Total |	1617920
#             Number of splices: Annotated (sjdb) |	1615355
#                        Number of splices: GT/AG |	1600874
#                        Number of splices: GC/AG |	13725
#                        Number of splices: AT/AC |	1267
#                Number of splices: Non-canonical |	2054
#                       Mismatch rate per base, % |	0.14%
#                          Deletion rate per base |	0.01%
#                         Deletion average length |	1.35
#                         Insertion rate per base |	0.01%
#                        Insertion average length |	1.20
#                              MULTI-MAPPING READS:
#         Number of reads mapped to multiple loci |	0
#              % of reads mapped to multiple loci |	0.00%
#         Number of reads mapped to too many loci |	2481837
#              % of reads mapped to too many loci |	20.47%
#                                   UNMAPPED READS:
#        % of reads unmapped: too many mismatches |	0.00%
#                  % of reads unmapped: too short |	0.51%
#                      % of reads unmapped: other |	0.11%
#
# ############################################################

# %% [markdown]
# ### 5. Read Quantification

# %%
# Create a folder for read counts
mkdir -p read_counts

# %%
# Count features using 8 threads ('-T 8')
featureCounts -a annotation/gene_annotation.gtf \
              -o read_counts/featureCounts_results.txt \
                 alignment_STAR/*bam -T 8
# Out:
#  ==========     _____ _    _ ____  _____  ______          _____
#         =====         / ____| |  | |  _ \|  __ \|  ____|   /\   |  __ \
#           =====      | (___ | |  | | |_) | |__) | |__     /  \  | |  | |
#             ====      \___ \| |  | |  _ <|  _  /|  __|   / /\ \ | |  | |
#               ====    ____) | |__| | |_) | | \ \| |____ / ____ \| |__| |
#         ==========   |_____/ \____/|____/|_|  \_\______/_/    \_\_____/
# 	  v1.6.4
#
# //========================== featureCounts setting ===========================\\
# ||                                                                            ||
# ||             Input files : 16 BAM files                                     ||
# ||                           S SRR7108388Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108389Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108390Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108391Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108392Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108393Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108394Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108395Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108396Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108397Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108398Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108399Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108400Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108401Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108402Aligned.sortedByCoord.out.bam        ||
# ||                           S SRR7108403Aligned.sortedByCoord.out.bam        ||
# ||                                                                            ||
# ||             Output file : featureCounts_results.txt                        ||
# ||                 Summary : featureCounts_results.txt.summary                ||
# ||              Annotation : gene_annotation.gtf (GTF)                        ||
# ||      Dir for temp files : read_counts                                      ||
# ||                                                                            ||
# ||                 Threads : 8                                                ||
# ||                   Level : meta-feature level                               ||
# ||              Paired-end : no                                               ||
# ||      Multimapping reads : not counted                                      ||
# || Multi-overlapping reads : not counted                                      ||
# ||   Min overlapping bases : 1                                                ||
# ||                                                                            ||
# \\============================================================================//
#
# //================================= Running ==================================\\
# ||                                                                            ||
# || Load annotation file gene_annotation.gtf ...                               ||
# ||    Features : 1279073                                                      ||
# ||    Meta-features : 58884                                                   ||
# ||    Chromosomes/contigs : 47                                                ||
# ||                                                                            ||
# || Process BAM file SRR7108388Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 8981757                                              ||
# ||    Successfully assigned alignments : 8107524 (90.3%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108389Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 9395707                                              ||
# ||    Successfully assigned alignments : 8465192 (90.1%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108390Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 9142611                                              ||
# ||    Successfully assigned alignments : 8247345 (90.2%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108391Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 8240328                                              ||
# ||    Successfully assigned alignments : 7426398 (90.1%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108392Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 9222057                                              ||
# ||    Successfully assigned alignments : 8364980 (90.7%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108393Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 9582820                                              ||
# ||    Successfully assigned alignments : 8693633 (90.7%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108394Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 10850498                                             ||
# ||    Successfully assigned alignments : 9776573 (90.1%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108395Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 8848325                                              ||
# ||    Successfully assigned alignments : 8001750 (90.4%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108396Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 10751555                                             ||
# ||    Successfully assigned alignments : 9586631 (89.2%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108397Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 9118221                                              ||
# ||    Successfully assigned alignments : 8135397 (89.2%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108398Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 9875251                                              ||
# ||    Successfully assigned alignments : 8802418 (89.1%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108399Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 11156245                                             ||
# ||    Successfully assigned alignments : 9983056 (89.5%)                      ||
# ||    Running time : 0.04 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108400Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 10432484                                             ||
# ||    Successfully assigned alignments : 9300927 (89.2%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108401Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 8702003                                              ||
# ||    Successfully assigned alignments : 7801982 (89.7%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108402Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 8946711                                              ||
# ||    Successfully assigned alignments : 8012872 (89.6%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# || Process BAM file SRR7108403Aligned.sortedByCoord.out.bam...                ||
# ||    Single-end reads are included.                                          ||
# ||    Assign alignments to features...                                        ||
# ||    Total alignments : 9568146                                              ||
# ||    Successfully assigned alignments : 8544013 (89.3%)                      ||
# ||    Running time : 0.03 minutes                                             ||
# ||                                                                            ||
# ||                                                                            ||
# || Summary of counting results can be found in file "read_counts/featureCoun  ||
# || ts_results.txt.summary"                                                    ||
# ||                                                                            ||
# \\============================================================================//
